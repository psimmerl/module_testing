# %% [markdown]
# # Light attenuation for LYSO
#
#
# Thoughts:
#
# -
#
# - Can we locate in 3D space the position of the source in the QAQC jig?
#
#
#
#
# # e^{-\frac{|x}}

# %%
import numpy as np

import matplotlib.pyplot as plt
# me, eg = 511, 511
# e = np.linspace(eg/(1+2*eg/me), eg, 10**3)
# y = me * (1/e - 1/eg)
# plt.plot(e, y)

x = np.linspace(-1, 1, 1000)
plt.plot(x, np.sin(np.arccos(x)))
plt.plot(x, (1-x**2)**0.5, "--")
